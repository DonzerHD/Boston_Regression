# %%
import pandas as pd
import numpy as np

# %%
# df = pd.read_excel('../data/Boston_Housing.xlsx', sheet_name='Data')

# %%
# créer un fichier csv
# df.to_csv('../data/bronze.csv', index=False)

# %%
df = pd.read_csv('../data/bronze.csv')

# %%
# Display the first few rows of the DataFrame
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
# Check the shape of the DataFrame
print("\nShape of the DataFrame:", df.shape)
# Out:
# Shape of the DataFrame: (506, 14)

# %%
# Check for missing values
print("\nMissing values in each column:\n", df.isnull().sum())
# Out:
# Missing values in each column:
#  CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
# Check for duplicate rows
print("\nNumber of duplicate rows:", df.duplicated().sum())
# Out:
# Number of duplicate rows: 0

# %%
# Check the data types of each column
print("\nData types of each column:\n", df.dtypes)
# Out:
# Data types of each column:
#  CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS         int64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX          int64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %%
# Check the distribution of values in each column
print("\nDistribution of values in each column:")
for col in df.columns:
    print(df[col].value_counts())
# Out:
# Distribution of values in each column:
# 0.01501     2
# 14.33370    2
# 0.03466     1
# 0.03113     1
# 0.03049     1
#            ..
# 1.51902     1
# 1.83377     1
# 1.46336     1
# 1.27346     1
# 0.04741     1
# Name: CRIM, Length: 504, dtype: int64
# 0.0      372
# 20.0      21
# 80.0      15
# 22.0      10
# 12.5      10
# 25.0      10
# 40.0       7
# 45.0       6
# 30.0       6
# 90.0       5
# 95.0       4
# 60.0       4
# 21.0       4
# 33.0       4
# 55.0       3
# 70.0       3
# 34.0       3
# 52.5       3
# 35.0       3
# 28.0       3
# 75.0       3
# 82.5       2
# 85.0       2
# 17.5       1
# 100.0      1
# 18.0       1
# Name: ZN, dtype: int64
# 18.10    132
# 19.58     30
# 8.14      22
# 6.20      18
# 21.89     15
#         ...
# 1.21       1
# 1.38       1
# 3.75       1
# 0.46       1
# 2.31       1
# Name: INDUS, Length: 76, dtype: int64
# 0    471
# 1     35
# Name: CHAS, dtype: int64
# 0.538    23
# 0.713    18
# 0.437    17
# 0.871    16
# 0.624    15
# ...

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
# Rename the columns
df.columns = ['crime_rate', 'residential_zone_pct', 'business_acres_pct', 'charles_river_dummy', 
              'nitric_oxides_concentration', 'average_rooms', 'age', 'distances_to_employment_centres', 
              'accessibility_to_highways', 'property_tax_rate', 'pupil_teacher_ratio', 'black_population', 
              'lower_status_pct', 'median_home_value']

# %%
# met dans un fichier csv
df.to_csv('../data/silver.csv', index=False)
