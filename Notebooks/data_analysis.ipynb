# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/silver.csv')

# %%
df.head()
# Out:
#    crime_rate  residential_zone_pct  business_acres_pct  charles_river_dummy  \
# 0     0.00632                  18.0                2.31                    0
# 1     0.02731                   0.0                7.07                    0
# 2     0.02729                   0.0                7.07                    0
# 3     0.03237                   0.0                2.18                    0
# 4     0.06905                   0.0                2.18                    0
#
#    nitric_oxides_concentration  average_rooms   age  \
# 0                        0.538          6.575  65.2
# 1                        0.469          6.421  78.9
# 2                        0.469          7.185  61.1
# 3                        0.458          6.998  45.8
# 4                        0.458          7.147  54.2
#
#    distances_to_employment_centres  accessibility_to_highways  \
# 0                           4.0900                          1
# 1                           4.9671                          2
# 2                           4.9671                          2
# 3                           6.0622                          3
# 4                           6.0622                          3
#
#    property_tax_rate  pupil_teacher_ratio  black_population  lower_status_pct  \
# 0                296                 15.3            396.90              4.98
# 1                242                 17.8            396.90              9.14
# 2                242                 17.8            392.83              4.03
# 3                222                 18.7            394.63              2.94
# 4                222                 18.7            396.90              5.33
#
#    median_home_value
# 0               24.0
# 1               21.6
# 2               34.7
# 3               33.4
# 4               36.2

# %%
# Plot histograms for each variable in the DataFrame
df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
# Calculate and display the correlation matrix
corr_matrix = df.corr()
corr_matrix
# Out:
#                                  crime_rate  residential_zone_pct  \
# crime_rate                         1.000000             -0.200469
# residential_zone_pct              -0.200469              1.000000
# business_acres_pct                 0.406583             -0.533828
# charles_river_dummy               -0.055892             -0.042697
# nitric_oxides_concentration        0.420972             -0.516604
# average_rooms                     -0.219247              0.311991
# age                                0.352734             -0.569537
# distances_to_employment_centres   -0.379670              0.664408
# accessibility_to_highways          0.625505             -0.311948
# property_tax_rate                  0.582764             -0.314563
# pupil_teacher_ratio                0.289946             -0.391679
# black_population                  -0.385064              0.175520
# lower_status_pct                   0.455621             -0.412995
# median_home_value                 -0.388305              0.360445
#
#                                  business_acres_pct  charles_river_dummy  \
# crime_rate                                 0.406583            -0.055892
# residential_zone_pct                      -0.533828            -0.042697
# business_acres_pct                         1.000000             0.062938
# charles_river_dummy                        0.062938             1.000000
# nitric_oxides_concentration                0.763651             0.091203
# average_rooms                             -0.391676             0.091251
# age                                        0.644779             0.086518
# distances_to_employment_centres           -0.708027            -0.099176
# accessibility_to_highways                  0.595129            -0.007368
# property_tax_rate                          0.720760            -0.035587
# pupil_teacher_ratio                        0.383248            -0.121515
# black_population                          -0.356977             0.048788
# lower_status_pct                           0.603800            -0.053929
# median_home_value                         -0.483725             0.175260
#
#                                  nitric_oxides_concentration  average_rooms  \
# crime_rate                                          0.420972      -0.219247
# residential_zone_pct                               -0.516604       0.311991
# business_acres_pct                                  0.763651      -0.391676
# charles_river_dummy                                 0.091203       0.091251
# nitric_oxides_concentration                         1.000000      -0.302188
# average_rooms                                      -0.302188       1.000000
# age                                                 0.731470      -0.240265
# distances_to_employment_centres                    -0.769230       0.205246
# accessibility_to_highways                           0.611441      -0.209847
# property_tax_rate                                   0.668023      -0.292048
# pupil_teacher_ratio                                 0.188933      -0.355501
# black_population                                   -0.380051       0.128069
# lower_status_pct                                    0.590879      -0.613808
# median_home_value                                  -0.427321       0.695360
#
#                                       age  distances_to_employment_centres  \
# crime_rate                       0.352734                        -0.379670
# residential_zone_pct            -0.569537                         0.664408
# business_acres_pct               0.644779                        -0.708027
# charles_river_dummy              0.086518                        -0.099176
# nitric_oxides_concentration      0.731470                        -0.769230
# average_rooms                   -0.240265                         0.205246
# age                              1.000000                        -0.747881
# distances_to_employment_centres -0.747881                         1.000000
# accessibility_to_highways        0.456022                        -0.494588
# property_tax_rate                0.506456                        -0.534432
# pupil_teacher_ratio              0.261515                        -0.232471
# black_population                -0.273534                         0.291512
# lower_status_pct                 0.602339                        -0.496996
# median_home_value               -0.376955                         0.249929
#
#                                  accessibility_to_highways  property_tax_rate  \
# crime_rate                                        0.625505           0.582764
# residential_zone_pct                             -0.311948          -0.314563
# business_acres_pct                                0.595129           0.720760
# charles_river_dummy                              -0.007368          -0.035587
# nitric_oxides_concentration                       0.611441           0.668023
# average_rooms                                    -0.209847          -0.292048
# age                                               0.456022           0.506456
# distances_to_employment_centres                  -0.494588          -0.534432
# accessibility_to_highways                         1.000000           0.910228
# property_tax_rate                                 0.910228           1.000000
# pupil_teacher_ratio                               0.464741           0.460853
# black_population                                 -0.444413          -0.441808
# lower_status_pct                                  0.488676           0.543993
# median_home_value                                -0.381626          -0.468536
#
#                                  pupil_teacher_ratio  black_population  \
# crime_rate                                  0.289946         -0.385064
# residential_zone_pct                       -0.391679          0.175520
# business_acres_pct                          0.383248         -0.356977
# charles_river_dummy                        -0.121515          0.048788
# nitric_oxides_concentration                 0.188933         -0.380051
# average_rooms                              -0.355501          0.128069
# age                                         0.261515         -0.273534
# distances_to_employment_centres            -0.232471          0.291512
# accessibility_to_highways                   0.464741         -0.444413
# property_tax_rate                           0.460853         -0.441808
# pupil_teacher_ratio                         1.000000         -0.177383
# black_population                           -0.177383          1.000000
# lower_status_pct                            0.374044         -0.366087
# median_home_value                          -0.507787          0.333461
#
#                                  lower_status_pct  median_home_value
# crime_rate                               0.455621          -0.388305
# residential_zone_pct                    -0.412995           0.360445
# business_acres_pct                       0.603800          -0.483725
# charles_river_dummy                     -0.053929           0.175260
# nitric_oxides_concentration              0.590879          -0.427321
# average_rooms                           -0.613808           0.695360
# age                                      0.602339          -0.376955
# distances_to_employment_centres         -0.496996           0.249929
# accessibility_to_highways                0.488676          -0.381626
# property_tax_rate                        0.543993          -0.468536
# pupil_teacher_ratio                      0.374044          -0.507787
# black_population                        -0.366087           0.333461
# lower_status_pct                         1.000000          -0.737663
# median_home_value                       -0.737663           1.000000

# %%
plt.figure(figsize=(20,15))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
# créer un fichier gold csv
df.to_csv('../data/gold.csv', index=False)
